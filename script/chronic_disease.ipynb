# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chronic_disease = pd.read_csv('../data/chronic_disease.csv')

# %%
chronic_disease
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0            2019     2019           GA         Georgia      BRFSS
# 1            2019     2019           GU            Guam      BRFSS
# 2            2019     2019           GU            Guam      BRFSS
# 3            2019     2019           ME           Maine      BRFSS
# 4            2019     2019           NV          Nevada       NVSS
# ...           ...      ...          ...             ...        ...
# 311740       2022     2022           VA        Virginia      BRFSS
# 311741       2022     2022           WA      Washington      BRFSS
# 311742       2022     2022           UT            Utah      BRFSS
# 311743       2022     2022           VI  Virgin Islands      BRFSS
# 311744       2022     2022           WI       Wisconsin      BRFSS
#
#                                                   Topic  \
# 0                                            Disability
# ...

# %%
chronic_disease.shape
# Out:
# (311745, 22)

# %%
chronic_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311745 entries, 0 to 311744
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   YearStart                311745 non-null  int64
#  1   YearEnd                  311745 non-null  int64
#  2   LocationAbbr             311745 non-null  object
#  3   LocationDesc             311745 non-null  object
#  4   DataSource               311745 non-null  object
#  5   Topic                    311745 non-null  object
#  6   Question                 311745 non-null  object
#  7   DataValueUnit            311745 non-null  object
#  8   DataValueType            311745 non-null  object
#  9   DataValue                210684 non-null  float64
#  10  DataValueAlt             210684 non-null  float64
#  11  DataValueFootnoteSymbol  102758 non-null  object
#  12  DataValueFootnote        102758 non-null  object
# ...

# %%
chronic_disease.isna().sum()
# Out:
# YearStart                       0
# YearEnd                         0
# LocationAbbr                    0
# LocationDesc                    0
# DataSource                      0
# Topic                           0
# Question                        0
# DataValueUnit                   0
# DataValueType                   0
# DataValue                  101061
# DataValueAlt               101061
# DataValueFootnoteSymbol    208987
# DataValueFootnote          208987
# LowConfidenceLimit         121372
# HighConfidenceLimit        121367
# StratificationCategory1         0
# Stratification1                 0
# StratificationCategory2    311745
# Stratification2            311745
# StratificationCategory3    311745
# Stratification3            311745
# Geolocation                  5809
# dtype: int64

# %%
chronic_disease.YearStart.value_counts()
# Out:
# YearStart
# 2019    88823
# 2021    87600
# 2020    67999
# 2022    47125
# 2016     8760
# 2015     8760
# 2018     2678
# Name: count, dtype: int64

# %%
chronic_disease.YearEnd.value_counts()
# Out:
# YearEnd
# 2019    95256
# 2021    85379
# 2020    79031
# 2022    52079
# Name: count, dtype: int64

# %%
chronic_disease.Topic.value_counts()
# Out:
# Topic
# Cardiovascular Disease                             30709
# Chronic Obstructive Pulmonary Disease              28216
# Nutrition, Physical Activity, and Weight Status    26069
# Health Status                                      25612
# Alcohol                                            25321
# Cancer                                             22358
# Arthritis                                          19910
# Immunization                                       19140
# Social Determinants of Health                      19026
# Diabetes                                           17318
# Mental Health                                      16976
# Tobacco                                            14740
# Oral Health                                        13236
# Asthma                                             10511
# Cognitive Health and Caregiving                     9904
# Sleep                                               5318
# ...

# %%
chronic_disease.Question.value_counts()
# Out:
# Question
# Binge drinking frequency among adults who binge drink                            5720
# Binge drinking intensity among adults who binge drink                            5680
# Diseases of the heart mortality among all people, underlying cause               5616
# Cerebrovascular disease (stroke) mortality among all people, underlying cause    5616
# Asthma mortality among all people, underlying cause                              5616
#                                                                                  ...
# Infants who were exclusively breastfed through 6 months                           122
# Infants who were breastfed at 12 months                                           122
# Incidence of treated end-stage kidney disease                                     104
# No broadband internet subscription among households                               104
# Food insecure in the past 12 months among households                               55
# ...

# %%
chronic_disease.LocationAbbr.value_counts()
# Out:
# LocationAbbr
# US    5809
# TN    5796
# GA    5794
# ND    5794
# MA    5794
# OR    5794
# MI    5794
# MO    5794
# CO    5794
# NY    5794
# CT    5794
# AR    5794
# MS    5794
# VA    5794
# WI    5794
# DE    5794
# NE    5794
# HI    5794
# UT    5794
# LA    5794
# MN    5794
# IL    5794
# DC    5794
# WA    5794
# VT    5794
# ME    5794
# PA    5794
# WY    5794
# NJ    5794
# KS    5794
# AL    5794
# MT    5788
# SD    5786
# NM    5786
# NH    5745
# MD    5745
# FL    5745
# IA    5745
# KY    5745
# WV    5745
# AK    5737
# NC    5696
# RI    5696
# OK    5696
# AZ    5688
# CA    5647
# OH    5647
# IN    5647
# TX    5647
# ID    5647
# NV    5647
# SC    5647
# PR    4212
# VI    4015
# GU    4015
# Name: count, dtype: int64

# %%
chronic_disease.loc[chronic_disease['Topic']== 'Cancer']
# Out:
#         YearStart  YearEnd LocationAbbr   LocationDesc     DataSource   Topic  \
# 34           2016     2020           US  United States  US Cancer DVT  Cancer
# 41           2015     2019           MO       Missouri  US Cancer DVT  Cancer
# 42           2015     2019           ID          Idaho  US Cancer DVT  Cancer
# 43           2015     2019           WY        Wyoming  US Cancer DVT  Cancer
# 44           2015     2019           AR       Arkansas  US Cancer DVT  Cancer
# ...           ...      ...          ...            ...            ...     ...
# 311596       2022     2022           WV  West Virginia          BRFSS  Cancer
# 311656       2022     2022           WV  West Virginia          BRFSS  Cancer
# 311661       2022     2022           UT           Utah          BRFSS  Cancer
# 311664       2022     2022           WY        Wyoming          BRFSS  Cancer
# 311689       2022     2022           WY        Wyoming          BRFSS  Cancer
#
# ...

# %%
chronic_disease =chronic_disease.rename(columns = str.lower)

# %%
list(chronic_disease.columns)
# Out:
# ['yearstart',
#  'yearend',
#  'locationabbr',
#  'locationdesc',
#  'datasource',
#  'topic',
#  'question',
#  'datavalueunit',
#  'datavaluetype',
#  'datavalue',
#  'datavaluealt',
#  'datavaluefootnotesymbol',
#  'datavaluefootnote',
#  'lowconfidencelimit',
#  'highconfidencelimit',
#  'stratificationcategory1',
#  'stratification1',
#  'stratificationcategory2',
#  'stratification2',
#  'stratificationcategory3',
#  'stratification3',
#  'geolocation']

# %%
columns_to_drop = ['yearend','datasource', 'datavaluealt', 'datavaluefootnotesymbol','lowconfidencelimit','highconfidencelimit','stratificationcategory2','stratification2','stratificationcategory3','stratification3']

# %%
chronic_disease.drop(columns=columns_to_drop, inplace=True)

# %%
chronic_disease
# Out:
#         yearstart locationabbr    locationdesc  \
# 0            2019           GA         Georgia
# 1            2019           GU            Guam
# 2            2019           GU            Guam
# 3            2019           ME           Maine
# 4            2019           NV          Nevada
# ...           ...          ...             ...
# 311740       2022           VA        Virginia
# 311741       2022           WA      Washington
# 311742       2022           UT            Utah
# 311743       2022           VI  Virgin Islands
# 311744       2022           WI       Wisconsin
#
#                                                   topic  \
# 0                                            Disability
# 1                                             Arthritis
# 2                                          Immunization
# 3                                              Diabetes
# 4                                         Health Status
# ...

# %%
obesity= pd.read_csv('../data/obesity.csv')

# %%
obesity
# Out:
#        YearStart LocationAbbr    LocationDesc                    Class  \
# 0           2011           AL         Alabama  Obesity / Weight Status
# 1           2011           AL         Alabama  Obesity / Weight Status
# 2           2011           AL         Alabama  Obesity / Weight Status
# 3           2011           AL         Alabama  Obesity / Weight Status
# 4           2011           AL         Alabama  Obesity / Weight Status
# ...          ...          ...             ...                      ...
# 58403       2017           VI  Virgin Islands  Obesity / Weight Status
# 58404       2017           VI  Virgin Islands  Obesity / Weight Status
# 58405       2017           VI  Virgin Islands  Obesity / Weight Status
# 58406       2017           VI  Virgin Islands  Obesity / Weight Status
# 58407       2017           VI  Virgin Islands  Obesity / Weight Status
#
#                          Topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# ...

# %%
obesity.isna().sum()
# Out:
# YearStart                  0
# LocationAbbr               0
# LocationDesc               0
# Class                      0
# Topic                      0
# Question                   0
# Data_Value_Unit        58408
# Data_Value_Type            0
# Data_Value              5727
# Data_Value_Footnote    52681
# Sample_Size             5727
# Total                  56322
# Age(years)             45892
# Education              50064
# Gender                 54236
# Income                 43806
# Race/Ethnicity         41720
# GeoLocation             1092
# dtype: int64

# %%
obesity =obesity.rename(columns = str.lower)

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58408 entries, 0 to 58407
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   yearstart            58408 non-null  int64
#  1   locationabbr         58408 non-null  object
#  2   locationdesc         58408 non-null  object
#  3   class                58408 non-null  object
#  4   topic                58408 non-null  object
#  5   question             58408 non-null  object
#  6   data_value_unit      0 non-null      float64
#  7   data_value_type      58408 non-null  object
#  8   data_value           52681 non-null  float64
#  9   data_value_footnote  5727 non-null   object
#  10  sample_size          52681 non-null  float64
#  11  total                2086 non-null   object
#  12  age(years)           12516 non-null  object
#  13  education            8344 non-null   object
#  14  gender               4172 non-null   object
# ...

# %%
list(obesity.columns)
# Out:
# ['yearstart',
#  'locationabbr',
#  'locationdesc',
#  'class',
#  'topic',
#  'question',
#  'data_value_unit',
#  'data_value_type',
#  'data_value',
#  'data_value_footnote',
#  'sample_size',
#  'total',
#  'age(years)',
#  'education',
#  'gender',
#  'income',
#  'race/ethnicity',
#  'geolocation']

# %%
obesity
# Out:
#        yearstart locationabbr    locationdesc                    class  \
# 0           2011           AL         Alabama  Obesity / Weight Status
# 1           2011           AL         Alabama  Obesity / Weight Status
# 2           2011           AL         Alabama  Obesity / Weight Status
# 3           2011           AL         Alabama  Obesity / Weight Status
# 4           2011           AL         Alabama  Obesity / Weight Status
# ...          ...          ...             ...                      ...
# 58403       2017           VI  Virgin Islands  Obesity / Weight Status
# 58404       2017           VI  Virgin Islands  Obesity / Weight Status
# 58405       2017           VI  Virgin Islands  Obesity / Weight Status
# 58406       2017           VI  Virgin Islands  Obesity / Weight Status
# 58407       2017           VI  Virgin Islands  Obesity / Weight Status
#
#                          topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# ...

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58408 entries, 0 to 58407
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   yearstart            58408 non-null  int64
#  1   locationabbr         58408 non-null  object
#  2   locationdesc         58408 non-null  object
#  3   class                58408 non-null  object
#  4   topic                58408 non-null  object
#  5   question             58408 non-null  object
#  6   data_value_unit      0 non-null      float64
#  7   data_value_type      58408 non-null  object
#  8   data_value           52681 non-null  float64
#  9   data_value_footnote  5727 non-null   object
#  10  sample_size          52681 non-null  float64
#  11  total                2086 non-null   object
#  12  age(years)           12516 non-null  object
#  13  education            8344 non-null   object
#  14  gender               4172 non-null   object
# ...

# %%
cd_cp = chronic_disease.loc[chronic_disease['datavaluetype'] == 'Crude Prevalence']

# %%
cd_cp1 = cd_cp.loc[cd_cp['stratificationcategory1'] == 'Sex']

# %%
list_of_disease = ['Arthritis','Lung Disease','Mental Health','Cardiovascular Disease','Alcohol','Chronic Obstructive Pulmonary Disease','Diabetes','Disability','Asthma','Cancer']

# %%
cd_cp2 = cd_cp1.loc[cd_cp1['topic'].isin(list_of_disease)]

# %%
cd_final = cd_cp2.loc[cd_cp2['datavaluefootnote'].isnull()]

# %%
cd_final
# Out:
#         yearstart locationabbr          locationdesc  \
# 1            2019           GU                  Guam
# 3            2019           ME                 Maine
# 6            2019           OK              Oklahoma
# 10           2020           AK                Alaska
# 11           2020           DC  District of Columbia
# ...           ...          ...                   ...
# 311674       2022           WY               Wyoming
# 311678       2022           WA            Washington
# 311694       2022           WY               Wyoming
# 311723       2022           VT               Vermont
# 311743       2022           VI        Virgin Islands
#
#                                         topic  \
# 1                                   Arthritis
# 3                                    Diabetes
# 6                                   Arthritis
# 10                                 Disability
# 11                                     Asthma
# ...

# %%
cd_final.topic.value_counts()
# Out:
# topic
# Arthritis                                1710
# Lung Disease                             1191
# Mental Health                             932
# Cardiovascular Disease                    856
# Chronic Obstructive Pulmonary Disease     840
# Alcohol                                   800
# Disability                                432
# Diabetes                                  430
# Asthma                                    430
# Cancer                                    218
# Name: count, dtype: int64

# %%
cd_final.to_csv('../data/cd_final.csv')

# %%
cd_top10= cd_final.groupby('topic')['datavalue'].mean().to_frame().reset_index()
cd_top10.sort_values(by = 'datavalue',ascending = False)
# Out:
#                                    topic  datavalue
# 3                                 Cancer  62.917431
# 4                 Cardiovascular Disease  44.629556
# 1                              Arthritis  33.800526
# 7                             Disability  28.686343
# 8                           Lung Disease  24.896054
# 5  Chronic Obstructive Pulmonary Disease  18.621905
# 9                          Mental Health  18.232296
# 0                                Alcohol  16.950500
# 6                               Diabetes  11.289070
# 2                                 Asthma  10.343721

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='topic', y='datavalue',data=cd_top10)
plt.title('Top 10 Chronic Disease')
plt.show();

# %%
plt.figure(figsize=(10, 6))
plt.barh(cd_top10['topic'], cd_top10['datavalue'])
plt.xlabel('Data Value')
plt.ylabel('Chronic Disease')
plt.title('Top 10 Chronic Diseases by Average Data Value')
plt.gca().invert_yaxis()  # Invert y-axis to display highest value at the top
plt.show()

# %%
cd_top10_by_year= cd_final.groupby(['yearstart','topic'])['datavalue'].mean().to_frame().reset_index()
cd_top10_by_year.sort_values(by=['yearstart', 'datavalue'], ascending=[True, False])
# Out:
#     yearstart                                  topic  datavalue
# 3        2019                 Cardiovascular Disease  43.730660
# 1        2019                              Arthritis  32.446226
# 6        2019                             Disability  28.655660
# 7        2019                           Lung Disease  26.692045
# 4        2019  Chronic Obstructive Pulmonary Disease  21.506161
# 0        2019                                Alcohol  18.261905
# 8        2019                          Mental Health  16.712736
# 5        2019                               Diabetes  10.911321
# 2        2019                                 Asthma  10.185849
# 11       2020                                 Cancer  65.655556
# 15       2020                           Lung Disease  35.072170
# 14       2020                             Disability  26.624074
# 12       2020  Chronic Obstructive Pulmonary Disease  20.273460
# 16       2020                          Mental Health  16.301852
# ...

# %%
plt.figure(figsize=(12, 8))
grouped = cd_top10_by_year.groupby(['yearstart', 'topic']).mean().unstack()
grouped.plot(kind='bar', stacked=False)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Data Value')
plt.title('Data Value of Chronic Diseases Over Time')
plt.legend(title='Topic', bbox_to_anchor=(1, .5), loc='center left')


# Show plot
#plt.tight_layout()
plt.show()

# %%
cd_age =cd_cp.loc[cd_cp['stratificationcategory1'] == 'Age']

# %%
cd_age
# Out:
#         yearstart locationabbr   locationdesc          topic  \
# 0            2019           GA        Georgia     Disability
# 5            2019           OH           Ohio      Arthritis
# 9            2020           AL        Alabama       Diabetes
# 39           2022           US  United States  Health Status
# 2760         2019           AK         Alaska      Arthritis
# ...           ...          ...            ...            ...
# 311701       2022           UT           Utah      Arthritis
# 311711       2022           WY        Wyoming   Immunization
# 311716       2022           WY        Wyoming  Health Status
# 311729       2022           UT           Utah  Health Status
# 311741       2022           WA     Washington          Sleep
#
#                                                  question datavalueunit  \
# 0                              Adults with any disability             %
# 5                                  Arthritis among adults             %
# ...

# %%
cd_age1= cd_age.loc[cd_age['datavaluefootnote'].isnull()]

# %%
cd_age1
# Out:
#         yearstart locationabbr   locationdesc          topic  \
# 0            2019           GA        Georgia     Disability
# 5            2019           OH           Ohio      Arthritis
# 9            2020           AL        Alabama       Diabetes
# 39           2022           US  United States  Health Status
# 2760         2019           AK         Alaska      Arthritis
# ...           ...          ...            ...            ...
# 311701       2022           UT           Utah      Arthritis
# 311711       2022           WY        Wyoming   Immunization
# 311716       2022           WY        Wyoming  Health Status
# 311729       2022           UT           Utah  Health Status
# 311741       2022           WA     Washington          Sleep
#
#                                                  question datavalueunit  \
# 0                              Adults with any disability             %
# 5                                  Arthritis among adults             %
# ...

# %%
age_group_stats = cd_age1.groupby(['stratification1', 'topic'])['datavalue'].mean().reset_index()
age_group_stats
# Out:
#    stratification1                                            topic  datavalue
# 0          Age 1-5                                      Oral Health  45.951442
# 1        Age 10-13  Nutrition, Physical Activity, and Weight Status  20.779808
# 2        Age 12-17                                      Oral Health  70.406731
# 3        Age 18-44                                          Alcohol  23.423148
# 4        Age 18-44                                        Arthritis  29.940931
# 5        Age 18-44                                           Asthma  10.680556
# 6        Age 18-44                           Cardiovascular Disease  21.945070
# 7        Age 18-44            Chronic Obstructive Pulmonary Disease  14.505296
# 8        Age 18-44                  Cognitive Health and Caregiving  17.358537
# 9        Age 18-44                                         Diabetes   3.242453
# 10       Age 18-44                                       Disability  21.032407
# ...

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Iterate over unique chronic diseases and plot their rates by age group
for disease in age_group_stats['topic'].unique():
    subset = age_group_stats[age_group_stats['topic'] == disease]
    plt.plot(subset['stratification1'], subset['datavalue'], marker='o', label=disease)

plt.xlabel('Age Group')
plt.ylabel('Average Rate')
plt.title('Rates of Chronic Diseases by Age Group')
plt.legend(bbox_to_anchor=(1, .5), loc='center left')
#plt.grid(True)
plt.show()

# %%
gender_stats = cd_final.groupby(['stratification1', 'topic'])['datavalue'].mean().reset_index()
gender_stats.sort_values(by = 'datavalue', ascending = False)
# Out:
#    stratification1                                  topic  datavalue
# 3           Female                                 Cancer  64.145872
# 13            Male                                 Cancer  61.688991
# 14            Male                 Cardiovascular Disease  44.736449
# 4           Female                 Cardiovascular Disease  44.522664
# 1           Female                              Arthritis  36.182360
# 11            Male                              Arthritis  31.413115
# 7           Female                             Disability  30.300463
# 17            Male                             Disability  27.072222
# 18            Male                           Lung Disease  25.172987
# 8           Female                           Lung Disease  24.618655
# 9           Female                          Mental Health  22.843777
# 5           Female  Chronic Obstructive Pulmonary Disease  19.490284
# 10            Male                                Alcohol  18.550250
# ...

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Iterate over unique chronic diseases and plot their prevalence rates by gender
for disease in gender_stats['topic'].unique():
    subset = gender_stats[gender_stats['topic'] == disease]
    plt.bar(subset['stratification1'], subset['datavalue'], label=disease)

plt.xlabel('Gender')
plt.ylabel('Prevalence')
plt.title('Prevalence of Chronic Diseases by Gender')
plt.legend(bbox_to_anchor=(1, .5), loc='center left')
plt.show()

# %%
cd_final
# Out:
#         yearstart locationabbr          locationdesc  \
# 1            2019           GU                  Guam
# 3            2019           ME                 Maine
# 6            2019           OK              Oklahoma
# 10           2020           AK                Alaska
# 11           2020           DC  District of Columbia
# ...           ...          ...                   ...
# 311674       2022           WY               Wyoming
# 311678       2022           WA            Washington
# 311694       2022           WY               Wyoming
# 311723       2022           VT               Vermont
# 311743       2022           VI        Virgin Islands
#
#                                         topic  \
# 1                                   Arthritis
# 3                                    Diabetes
# 6                                   Arthritis
# 10                                 Disability
# 11                                     Asthma
# ...

# %%
state_stats = cd_final.groupby(['locationdesc', 'topic'])['datavalue'].mean().reset_index()
state_stats
# Out:
#     locationdesc                                  topic  datavalue
# 0        Alabama                                Alcohol  14.592857
# 1        Alabama                              Arthritis  37.903125
# 2        Alabama                                 Asthma   9.987500
# 3        Alabama                                 Cancer  66.825000
# 4        Alabama                 Cardiovascular Disease  50.481250
# ..           ...                                    ...        ...
# 544      Wyoming  Chronic Obstructive Pulmonary Disease  17.675000
# 545      Wyoming                               Diabetes   8.662500
# 546      Wyoming                             Disability  27.700000
# 547      Wyoming                           Lung Disease  28.833333
# 548      Wyoming                          Mental Health  16.968750
#
# [549 rows x 3 columns]

# %%
highest_rates = state_stats.groupby('topic').max().reset_index()
highest_rates.sort_values(by = 'datavalue', ascending = False)
# Out:
#                                    topic locationdesc  datavalue
# 3                                 Cancer      Wyoming  71.550000
# 4                 Cardiovascular Disease      Wyoming  51.437500
# 7                             Disability      Wyoming  43.387500
# 1                              Arthritis      Wyoming  42.675000
# 8                           Lung Disease      Wyoming  35.295000
# 5  Chronic Obstructive Pulmonary Disease      Wyoming  26.275000
# 9                          Mental Health      Wyoming  25.055556
# 0                                Alcohol      Wyoming  23.791667
# 6                               Diabetes      Wyoming  16.962500
# 2                                 Asthma      Wyoming  12.737500

# %%
lowest_rates = state_stats.groupby('topic').min().reset_index()
lowest_rates.sort_values(by = 'datavalue', ascending = True)
# Out:
#                                    topic locationdesc  datavalue
# 5  Chronic Obstructive Pulmonary Disease      Alabama   0.900000
# 8                           Lung Disease      Alabama   3.000000
# 2                                 Asthma      Alabama   6.114286
# 6                               Diabetes      Alabama   7.275000
# 0                                Alcohol      Alabama   9.150000
# 9                          Mental Health      Alabama   9.325000
# 7                             Disability      Alabama  21.650000
# 1                              Arthritis      Alabama  30.121875
# 4                 Cardiovascular Disease      Alabama  38.125000
# 3                                 Cancer      Alabama  42.825000

# %%
cd_race =cd_cp.loc[cd_cp['stratificationcategory1'] == 'Race/Ethnicity']
cd_race
# Out:
#         yearstart locationabbr    locationdesc  \
# 13552        2019           AL         Alabama
# 13554        2019           AK          Alaska
# 13560        2019           AK          Alaska
# 13561        2018           NE        Nebraska
# 13576        2018           AR        Arkansas
# ...           ...          ...             ...
# 311722       2022           WY         Wyoming
# 311725       2022           WY         Wyoming
# 311727       2022           VI  Virgin Islands
# 311734       2022           WY         Wyoming
# 311742       2022           UT            Utah
#
#                                                   topic  \
# 13552                            Cardiovascular Disease
# 13554                                           Tobacco
# 13560                                         Arthritis
# 13561                                       Oral Health
# 13576   Nutrition, Physical Activity, and Weight Status
# ...

# %%
cd_race1= cd_race.loc[cd_race['datavaluefootnote'].isnull()]
cd_race1
# Out:
#         yearstart locationabbr   locationdesc  \
# 13552        2019           AL        Alabama
# 13554        2019           AK         Alaska
# 13560        2019           AK         Alaska
# 13600        2019           AK         Alaska
# 13606        2019           AL        Alabama
# ...           ...          ...            ...
# 311684       2022           VA       Virginia
# 311693       2022           VT        Vermont
# 311708       2022           US  United States
# 311721       2022           US  United States
# 311722       2022           WY        Wyoming
#
#                                                   topic  \
# 13552                            Cardiovascular Disease
# 13554                                           Tobacco
# 13560                                         Arthritis
# 13600                                          Diabetes
# 13606                                        Disability
# ...                                                 ...
# ...

# %%
ethnicity_stats = cd_race1.groupby(['stratification1', 'topic'])['datavalue'].mean().reset_index()
ethnicity_stats
# Out:
#                                     stratification1  \
# 0    American Indian or Alaska Native, non-Hispanic
# 1    American Indian or Alaska Native, non-Hispanic
# 2    American Indian or Alaska Native, non-Hispanic
# 3    American Indian or Alaska Native, non-Hispanic
# 4    American Indian or Alaska Native, non-Hispanic
# ..                                              ...
# 122                             White, non-Hispanic
# 123                             White, non-Hispanic
# 124                             White, non-Hispanic
# 125                             White, non-Hispanic
# 126                             White, non-Hispanic
#
#                                                topic  datavalue
# 0                                            Alcohol  18.741129
# 1                                          Arthritis  37.066800
# 2                                             Asthma  14.971429
# 3                                             Cancer  60.209836
# ...

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Iterate over unique chronic diseases and plot their prevalence rates by racial/ethnic group
for disease in ethnicity_stats['topic'].unique():
    subset = ethnicity_stats[ethnicity_stats['topic'] == disease]
    plt.bar(subset['stratification1'], subset['datavalue'], label=disease)

plt.xlabel('Racial/Ethnic Group')
plt.ylabel('Prevalence')
plt.title('Prevalence of Chronic Diseases by Racial/Ethnic Group')
plt.legend(bbox_to_anchor=(1, .5), loc='center left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='stratification1', y='datavalue',data=ethnicity_stats)
plt.title('Prevalence of Chronic Diseases by Racial/Ethnic Group')
plt.show();

# %%
cd_final
# Out:
#         yearstart locationabbr          locationdesc  \
# 1            2019           GU                  Guam
# 3            2019           ME                 Maine
# 6            2019           OK              Oklahoma
# 10           2020           AK                Alaska
# 11           2020           DC  District of Columbia
# ...           ...          ...                   ...
# 311674       2022           WY               Wyoming
# 311678       2022           WA            Washington
# 311694       2022           WY               Wyoming
# 311723       2022           VT               Vermont
# 311743       2022           VI        Virgin Islands
#
#                                         topic  \
# 1                                   Arthritis
# 3                                    Diabetes
# 6                                   Arthritis
# 10                                 Disability
# 11                                     Asthma
# ...

# %%
obe = obesity.loc[obesity['data_value_footnote'].isnull()]
obe
# Out:
#        yearstart locationabbr locationdesc                    class  \
# 0           2011           AL      Alabama  Obesity / Weight Status
# 1           2011           AL      Alabama  Obesity / Weight Status
# 2           2011           AL      Alabama  Obesity / Weight Status
# 3           2011           AL      Alabama  Obesity / Weight Status
# 4           2011           AL      Alabama  Obesity / Weight Status
# ...          ...          ...          ...                      ...
# 58340       2017           PR  Puerto Rico  Obesity / Weight Status
# 58341       2017           PR  Puerto Rico  Obesity / Weight Status
# 58342       2017           PR  Puerto Rico  Obesity / Weight Status
# 58343       2017           PR  Puerto Rico  Obesity / Weight Status
# 58346       2017           PR  Puerto Rico  Obesity / Weight Status
#
#                          topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# 2      Obesity / Weight Status
# ...

# %%
obe.question.value_counts()
# Out:
# question
# Percent of adults aged 18 years and older who have obesity                                                                                                                                                                                               9499
# Percent of adults aged 18 years and older who have an overweight classification                                                                                                                                                                          9499
# Percent of adults who engage in no leisure-time physical activity                                                                                                                                                                                        9491
# ...

# %%
obe1 =obe.loc[obe.question.isin(['Percent of adults aged 18 years and older who have obesity','Percent of adults aged 18 years and older who have an overweight classification'])]

# %%
obe1
# Out:
#        yearstart locationabbr locationdesc                    class  \
# 0           2011           AL      Alabama  Obesity / Weight Status
# 1           2011           AL      Alabama  Obesity / Weight Status
# 2           2011           AL      Alabama  Obesity / Weight Status
# 3           2011           AL      Alabama  Obesity / Weight Status
# 4           2011           AL      Alabama  Obesity / Weight Status
# ...          ...          ...          ...                      ...
# 58340       2017           PR  Puerto Rico  Obesity / Weight Status
# 58341       2017           PR  Puerto Rico  Obesity / Weight Status
# 58342       2017           PR  Puerto Rico  Obesity / Weight Status
# 58343       2017           PR  Puerto Rico  Obesity / Weight Status
# 58346       2017           PR  Puerto Rico  Obesity / Weight Status
#
#                          topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# 2      Obesity / Weight Status
# ...

# %%
obe2 = obe1.loc[obe1['topic']== 'Obesity / Weight Status']

# %%
chronic_disease
# Out:
#         yearstart locationabbr    locationdesc  \
# 0            2019           GA         Georgia
# 1            2019           GU            Guam
# 2            2019           GU            Guam
# 3            2019           ME           Maine
# 4            2019           NV          Nevada
# ...           ...          ...             ...
# 311740       2022           VA        Virginia
# 311741       2022           WA      Washington
# 311742       2022           UT            Utah
# 311743       2022           VI  Virgin Islands
# 311744       2022           WI       Wisconsin
#
#                                                   topic  \
# 0                                            Disability
# 1                                             Arthritis
# 2                                          Immunization
# 3                                              Diabetes
# 4                                         Health Status
# ...

# %%
test_n = chronic_disease.loc[chronic_disease['datavaluetype'] == 'Crude Prevalence']
test_n
# Out:
#         yearstart locationabbr    locationdesc          topic  \
# 0            2019           GA         Georgia     Disability
# 1            2019           GU            Guam      Arthritis
# 2            2019           GU            Guam   Immunization
# 3            2019           ME           Maine       Diabetes
# 5            2019           OH            Ohio      Arthritis
# ...           ...          ...             ...            ...
# 311729       2022           UT            Utah  Health Status
# 311734       2022           WY         Wyoming   Immunization
# 311741       2022           WA      Washington          Sleep
# 311742       2022           UT            Utah   Immunization
# 311743       2022           VI  Virgin Islands  Mental Health
#
#                                                  question datavalueunit  \
# 0                              Adults with any disability             %
# 1                                  Arthritis among adults             %
# ...

# %%
test_n1 = test_n.loc[test_n['datavaluefootnote'].isnull()]
test_n1
# Out:
#         yearstart locationabbr    locationdesc          topic  \
# 0            2019           GA         Georgia     Disability
# 1            2019           GU            Guam      Arthritis
# 2            2019           GU            Guam   Immunization
# 3            2019           ME           Maine       Diabetes
# 5            2019           OH            Ohio      Arthritis
# ...           ...          ...             ...            ...
# 311722       2022           WY         Wyoming  Health Status
# 311723       2022           VT         Vermont  Mental Health
# 311729       2022           UT            Utah  Health Status
# 311741       2022           WA      Washington          Sleep
# 311743       2022           VI  Virgin Islands  Mental Health
#
#                                          question datavalueunit  \
# 0                      Adults with any disability             %
# 1                          Arthritis among adults             %
# ...

# %%
n_test =test_n1.loc[test_n1['stratificationcategory1']== 'Age' ]
n_test
# Out:
#         yearstart locationabbr   locationdesc          topic  \
# 0            2019           GA        Georgia     Disability
# 5            2019           OH           Ohio      Arthritis
# 9            2020           AL        Alabama       Diabetes
# 39           2022           US  United States  Health Status
# 2760         2019           AK         Alaska      Arthritis
# ...           ...          ...            ...            ...
# 311701       2022           UT           Utah      Arthritis
# 311711       2022           WY        Wyoming   Immunization
# 311716       2022           WY        Wyoming  Health Status
# 311729       2022           UT           Utah  Health Status
# 311741       2022           WA     Washington          Sleep
#
#                                                  question datavalueunit  \
# 0                              Adults with any disability             %
# 5                                  Arthritis among adults             %
# ...

# %%
n_final =n_test.loc[n_test['stratification1']== 'Age >=65' ]
n_final
# Out:
#         yearstart locationabbr   locationdesc          topic  \
# 0            2019           GA        Georgia     Disability
# 5            2019           OH           Ohio      Arthritis
# 3143         2019           CO       Colorado     Disability
# 13802        2019           AR       Arkansas       Diabetes
# 13865        2019           AK         Alaska  Health Status
# ...           ...          ...            ...            ...
# 311532       2022           WV  West Virginia       Diabetes
# 311538       2022           WV  West Virginia          Sleep
# 311649       2022           UT           Utah         Asthma
# 311729       2022           UT           Utah  Health Status
# 311741       2022           WA     Washington          Sleep
#
#                                          question datavalueunit  \
# 0                      Adults with any disability             %
# 5                          Arthritis among adults             %
# ...

# %%
ob_test = obe2.loc[obe2['age(years)']== '65 or older' ]
ob_test
# Out:
#        yearstart locationabbr   locationdesc                    class  \
# 12          2011           AL        Alabama  Obesity / Weight Status
# 40          2011           AL        Alabama  Obesity / Weight Status
# 210         2012           AL        Alabama  Obesity / Weight Status
# 239         2012           AL        Alabama  Obesity / Weight Status
# 296         2013           AL        Alabama  Obesity / Weight Status
# ...          ...          ...            ...                      ...
# 58202       2017           WA     Washington  Obesity / Weight Status
# 58229       2017           WV  West Virginia  Obesity / Weight Status
# 58256       2017           WI      Wisconsin  Obesity / Weight Status
# 58283       2017           WY        Wyoming  Obesity / Weight Status
# 58336       2017           PR    Puerto Rico  Obesity / Weight Status
#
#                          topic  \
# 12     Obesity / Weight Status
# 40     Obesity / Weight Status
# ...

# %% [markdown]
# ## corelation bw chronic disease and obesity with age >65

# %%
n_final_dropna = n_final.dropna(subset=['datavalue'])
ob_test_dropna = ob_test.dropna(subset=['data_value'])

# %%
min_len = min(len(n_final_dropna), len(ob_test_dropna))
n_final_dropna = n_final_dropna[:min_len]
ob_test_dropna = ob_test_dropna[:min_len]

# %%
corr_without_null = n_final_dropna['datavalue'].corr(ob_test_dropna['data_value'], method='pearson', min_periods=1)
corr_without_null
# Out:
# 0.16652922248978116

# %%
plt.figure(figsize=(8, 6))
plt.scatter(n_final_dropna['datavalue'], ob_test_dropna['data_value'], alpha=0.5)
plt.title('Corelation bw Chronic Disease and Obesity (age over 65)')
plt.xlabel('Chronic Disease datavalue ')
plt.ylabel('Obesity datavalue')
#plt.grid(True)
# Out:
# Text(0, 0.5, 'Obesity datavalue')

# %%
list(obesity.columns)
# Out:
# ['yearstart',
#  'locationabbr',
#  'locationdesc',
#  'class',
#  'topic',
#  'question',
#  'data_value_unit',
#  'data_value_type',
#  'data_value',
#  'data_value_footnote',
#  'sample_size',
#  'total',
#  'age(years)',
#  'education',
#  'gender',
#  'income',
#  'race/ethnicity',
#  'geolocation']

# %%
#relevant_columns = ['yearstart', 'locationabbr', 'locationdesc', 'class', 'topic', 'question',
                    #'data_value_unit', 'data_value_type', 'data_value', 'age(years)', 'gender']
filtered_obesity = obesity[(obesity['topic'] == 'Physical Activity - Behavior') & 
                           (obesity['question'] == 'Percent of adults who engage in no leisure-time physical activity')& (obesity['class'] == 'Physical Activity') & obesity['data_value_footnote'].isnull() ]

# %%
filtered_obesity
# Out:
#        yearstart locationabbr locationdesc              class  \
# 169         2011           AL      Alabama  Physical Activity
# 170         2011           AL      Alabama  Physical Activity
# 171         2011           AL      Alabama  Physical Activity
# 172         2011           AL      Alabama  Physical Activity
# 173         2011           AL      Alabama  Physical Activity
# ...          ...          ...          ...                ...
# 49072       2017           PR  Puerto Rico  Physical Activity
# 49073       2017           PR  Puerto Rico  Physical Activity
# 49074       2017           PR  Puerto Rico  Physical Activity
# 49075       2017           PR  Puerto Rico  Physical Activity
# 49078       2017           PR  Puerto Rico  Physical Activity
#
#                               topic  \
# 169    Physical Activity - Behavior
# 170    Physical Activity - Behavior
# 171    Physical Activity - Behavior
# 172    Physical Activity - Behavior
# ...

# %%
muscle_strengthening =  obesity[(obesity['topic'] == 'Physical Activity - Behavior') & 
                           (obesity['question'] == 'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week')& (obesity['class'] == 'Physical Activity')& test_n['datavaluefootnote'].isnull() ]
# Out:
# C:\Users\Bharg\AppData\Local\Temp\ipykernel_23760\1263334932.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   muscle_strengthening =  obesity[(obesity['topic'] == 'Physical Activity - Behavior') &

# %%
muscle_strengthening
# Out:
#        yearstart locationabbr    locationdesc              class  \
# 3818        2013           CT     Connecticut  Physical Activity
# 13408       2013           MN       Minnesota  Physical Activity
# 13681       2011           MS     Mississippi  Physical Activity
# 13682       2011           MS     Mississippi  Physical Activity
# 13684       2011           MS     Mississippi  Physical Activity
# ...          ...          ...             ...                ...
# 52213       2017           VI  Virgin Islands  Physical Activity
# 52215       2017           VI  Virgin Islands  Physical Activity
# 52218       2017           VI  Virgin Islands  Physical Activity
# 52219       2017           VI  Virgin Islands  Physical Activity
# 52221       2017           VI  Virgin Islands  Physical Activity
#
#                               topic  \
# 3818   Physical Activity - Behavior
# 13408  Physical Activity - Behavior
# 13681  Physical Activity - Behavior
# ...

# %%
chronic_disease
# Out:
#         yearstart locationabbr    locationdesc  \
# 0            2019           GA         Georgia
# 1            2019           GU            Guam
# 2            2019           GU            Guam
# 3            2019           ME           Maine
# 4            2019           NV          Nevada
# ...           ...          ...             ...
# 311740       2022           VA        Virginia
# 311741       2022           WA      Washington
# 311742       2022           UT            Utah
# 311743       2022           VI  Virgin Islands
# 311744       2022           WI       Wisconsin
#
#                                                   topic  \
# 0                                            Disability
# 1                                             Arthritis
# 2                                          Immunization
# 3                                              Diabetes
# 4                                         Health Status
# ...

# %%
list(chronic_disease.columns)
# Out:
# ['yearstart',
#  'locationabbr',
#  'locationdesc',
#  'topic',
#  'question',
#  'datavalueunit',
#  'datavaluetype',
#  'datavalue',
#  'datavaluefootnote',
#  'stratificationcategory1',
#  'stratification1',
#  'geolocation']

# %%
dcd = chronic_disease.loc[chronic_disease['datavaluetype'] == 'Crude Prevalence']

# %%
dcd1 = dcd.loc[dcd['datavaluefootnote'].isnull()]

# %%
dcd2 = dcd1.loc[dcd1['topic'] == 'Diabetes']

# %%
dcd3= dcd2.loc[dcd2['stratificationcategory1'] == 'Age']

# %%
years = range(2019, 2023)

# %%
dcd4 = dcd3.loc[dcd3['yearstart'].isin (years)]
dcd4
# Out:
#         yearstart locationabbr    locationdesc     topic  \
# 9            2020           AL         Alabama  Diabetes
# 13802        2019           AR        Arkansas  Diabetes
# 14265        2019           AK          Alaska  Diabetes
# 16612        2019           AZ         Arizona  Diabetes
# 17787        2019           AL         Alabama  Diabetes
# ...           ...          ...             ...       ...
# 310167       2022           VI  Virgin Islands  Diabetes
# 310330       2022           WA      Washington  Diabetes
# 310332       2022           WY         Wyoming  Diabetes
# 310975       2022           WI       Wisconsin  Diabetes
# 311532       2022           WV   West Virginia  Diabetes
#
#                      question datavalueunit     datavaluetype  datavalue  \
# 9       Diabetes among adults             %  Crude Prevalence        5.0
# 13802   Diabetes among adults             %  Crude Prevalence       25.3
# ...

# %%
prevalence = dcd4['datavalue'].mean()
prevalence
# Out:
# 13.60436137071651

# %%
prevalence_by_year = dcd4.groupby('yearstart')['datavalue'].mean()
prevalence_by_year
# Out:
# yearstart
# 2019    13.388608
# 2020    13.350625
# 2021    13.350625
# 2022    14.307317
# Name: datavalue, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.bar(prevalence_by_year.index, prevalence_by_year, color='skyblue')
plt.title('Prevalence of Diagnosed Diabetes (2019-2022)')
plt.xlabel('Year')
plt.ylabel('Prevalence (%)')
plt.xticks(prevalence_by_year.index)
#plt.grid(axis='y')
plt.axhline(y=prevalence_by_year.mean(), color='r', linestyle='--', label='Average Prevalence')
plt.legend(bbox_to_anchor=(1, .5), loc='upper left')
plt.tight_layout()
plt.show()

# %%
medicare = pd.read_csv('../data/medicare hospital spending by claim.csv')
medicare
# Out:
#        Facility ID                             Facility Name State  \
# 0            10001          SOUTHEAST ALABAMA MEDICAL CENTER    AL
# 1            10001          SOUTHEAST ALABAMA MEDICAL CENTER    AL
# 2            10001          SOUTHEAST ALABAMA MEDICAL CENTER    AL
# 3            10001          SOUTHEAST ALABAMA MEDICAL CENTER    AL
# 4            10001          SOUTHEAST ALABAMA MEDICAL CENTER    AL
# ...            ...                                       ...   ...
# 67821       670122  HOUSTON METHODIST THE WOODLANDS HOSPITAL    TX
# 67822       670122  HOUSTON METHODIST THE WOODLANDS HOSPITAL    TX
# 67823       670122  HOUSTON METHODIST THE WOODLANDS HOSPITAL    TX
# 67824       670122  HOUSTON METHODIST THE WOODLANDS HOSPITAL    TX
# 67825       670122  HOUSTON METHODIST THE WOODLANDS HOSPITAL    TX
#
#                                                   Period  \
# 0          1 to 3 days Prior to Index Hospital Admission
# ...

# %%
list(medicare.columns)
# Out:
# ['Facility ID',
#  'Facility Name',
#  'State',
#  'Period',
#  'Claim Type',
#  'Avg Spending Per Episode Hospital',
#  'Avg Spending Per Episode State',
#  'Avg Spending Per Episode Nation',
#  'Percent of Spending Hospital',
#  'Percent of Spending State',
#  'Percent of Spending Nation',
#  'Start Date',
#  'End Date']

# %%
obesity['class'].value_counts()
# Out:
# class
# Physical Activity          34328
# Obesity / Weight Status    21000
# Fruits and Vegetables       3080
# Name: count, dtype: int64

# %%
obesity['question'].value_counts()
# Out:
# question
# Percent of adults aged 18 years and older who have obesity                                                                                                                                                                                               10500
# Percent of adults aged 18 years and older who have an overweight classification                                                                                                                                                                          10500
# Percent of adults who engage in no leisure-time physical activity                                                                                                                                                                                        10472
# ...

# %%
list(chronic_disease.columns)
# Out:
# ['yearstart',
#  'locationabbr',
#  'locationdesc',
#  'topic',
#  'question',
#  'datavalueunit',
#  'datavaluetype',
#  'datavalue',
#  'datavaluefootnote',
#  'stratificationcategory1',
#  'stratification1',
#  'geolocation']

# %%
chronic_disease[['stratificationcategory1','stratification1']]
# Out:
#        stratificationcategory1                                 stratification1
# 0                          Age                                        Age >=65
# 1                          Sex                                          Female
# 2                          Sex                                            Male
# 3                          Sex                                            Male
# 4                      Overall                                         Overall
# ...                        ...                                             ...
# 311740          Race/Ethnicity                       Multiracial, non-Hispanic
# 311741                     Age                                        Age >=65
# 311742          Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
# 311743                     Sex                                            Male
# 311744                     Sex                                            Male
#
# ...

# %%
list(obesity.columns)
# Out:
# ['yearstart',
#  'locationabbr',
#  'locationdesc',
#  'class',
#  'topic',
#  'question',
#  'data_value_unit',
#  'data_value_type',
#  'data_value',
#  'data_value_footnote',
#  'sample_size',
#  'total',
#  'age(years)',
#  'education',
#  'gender',
#  'income',
#  'race/ethnicity',
#  'geolocation']

# %%
chronic_disease.columns
# Out:
# Index(['yearstart', 'locationabbr', 'locationdesc', 'topic', 'question',
#        'datavalueunit', 'datavaluetype', 'datavalue', 'datavaluefootnote',
#        'stratificationcategory1', 'stratification1', 'geolocation'],
#       dtype='object')

# %%
obesity.shape
# Out:
# (58408, 18)
