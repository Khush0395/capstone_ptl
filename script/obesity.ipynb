# %%
import pandas as pd

# %%
obesity= pd.read_csv('../data/obesity.csv')

# %%
obesity
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 58403       2017     2017           VI  Virgin Islands
# 58404       2017     2017           VI  Virgin Islands
# 58405       2017     2017           VI  Virgin Islands
# 58406       2017     2017           VI  Virgin Islands
# 58407       2017     2017           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
obesity.isna().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               58408
# Data_Value_Type                   0
# Data_Value                     5727
# Data_Value_Alt                 5727
# Data_Value_Footnote_Symbol    52681
# Data_Value_Footnote           52681
# Low_Confidence_Limit           5727
# High_Confidence_Limit          5727
# Sample_Size                    5727
# Total                         56322
# Age(years)                    45892
# Education                     50064
# Gender                        54236
# Income                        43806
# Race/Ethnicity                41720
# GeoLocation                    1092
# ClassID                           0
# TopicID                           0
# ...

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58408 entries, 0 to 58407
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   58408 non-null  int64
#  1   YearEnd                     58408 non-null  int64
#  2   LocationAbbr                58408 non-null  object
#  3   LocationDesc                58408 non-null  object
#  4   Datasource                  58408 non-null  object
#  5   Class                       58408 non-null  object
#  6   Topic                       58408 non-null  object
#  7   Question                    58408 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             58408 non-null  object
#  10  Data_Value                  52681 non-null  float64
#  11  Data_Value_Alt              52681 non-null  float64
#  12  Data_Value_Footnote_Symbol  5727 non-null   object
# ...
