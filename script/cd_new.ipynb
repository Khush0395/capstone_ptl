# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chronic_disease = pd.read_csv('../data/chronic_disease.csv')

# %%
chronic_disease
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0            2019     2019           GA         Georgia      BRFSS
# 1            2019     2019           GU            Guam      BRFSS
# 2            2019     2019           GU            Guam      BRFSS
# 3            2019     2019           ME           Maine      BRFSS
# 4            2019     2019           NV          Nevada       NVSS
# ...           ...      ...          ...             ...        ...
# 311740       2022     2022           VA        Virginia      BRFSS
# 311741       2022     2022           WA      Washington      BRFSS
# 311742       2022     2022           UT            Utah      BRFSS
# 311743       2022     2022           VI  Virgin Islands      BRFSS
# 311744       2022     2022           WI       Wisconsin      BRFSS
#
#                                                   Topic  \
# 0                                            Disability
# ...

# %%
chronic_disease =chronic_disease.rename(columns = str.lower)

# %% [markdown]
# # top moratality diseases per 100000

# %%
c1 =chronic_disease['question'].str.lower().str.contains('mortality')
c1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 311740    False
# 311741    False
# 311742    False
# 311743    False
# 311744    False
# Name: question, Length: 311745, dtype: bool

# %%
columns_with_mortality = [col for col in chronic_disease.question if 'mortality' in col.lower()]
columns_with_mortality
# Out:
# ['Asthma mortality among all people, underlying cause',
#  'Coronary heart disease mortality among all people, underlying cause',
#  'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#  'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#  'Cervical cancer mortality among all females, underlying cause',
#  'Cervical cancer mortality among all females, underlying cause',
#  'Breast cancer mortality among all females, underlying cause',
#  'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#  'Prostate cancer mortality among all males, underlying cause',
#  'Prostate cancer mortality among all males, underlying cause',
#  'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#  'Lung and bronchial cancer mortality among all people, underlying cause',
#  'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
# ...
